# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\Dell\Desktop\archive\housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.loc[0]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age        41.0
# total_rooms              880.0
# total_bedrooms           129.0
# population               322.0
# households               126.0
# median_income           8.3252
# median_house_value    452600.0
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %%
df.loc[0:5]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
# 5    -122.25     37.85                52.0        919.0           213.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
# ...

# %%
df.loc[0:5,['total_bedrooms','latitude']]
# Out:
#    total_bedrooms  latitude
# 0           129.0     37.88
# 1          1106.0     37.86
# 2           190.0     37.85
# 3           235.0     37.85
# 4           280.0     37.85
# 5           213.0     37.85

# %%
df.loc[0:10,['total_rooms','median_income']]
# Out:
#     total_rooms  median_income
# 0         880.0         8.3252
# 1        7099.0         8.3014
# 2        1467.0         7.2574
# 3        1274.0         5.6431
# 4        1627.0         3.8462
# 5         919.0         4.0368
# 6        2535.0         3.6591
# 7        3104.0         3.1200
# 8        2555.0         2.0804
# 9        3549.0         3.6912
# 10       2202.0         3.2031

# %%
df=pd.read_csv(r'C:\Users\Dell\Desktop\match.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13124\3201307916.py in <module>
# ----> 1 df=pd.read_csv(r'C:\Users\Dell\Desktop\matches.csv')
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
