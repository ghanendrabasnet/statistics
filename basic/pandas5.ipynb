# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("D:\\mov.csv")

# %%
df
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
df.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
df.tail()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 995  Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                   Giant          1956      201   Drama          7.6
# 997   From Here to Eternity          1953      118   Drama          7.6
# 998                Lifeboat          1944       97   Drama          7.6
# 999            The 39 Steps          1935       86   Crime          7.6
#
#              Director              Star1  No_of_Votes        Gross  Metascore
# 995     Blake Edwards     Audrey Hepburn       166544  679874270.0       76.0
# 996    George Stevens   Elizabeth Taylor        34075  195217415.0       84.0
# 997    Fred Zinnemann     Burt Lancaster        43374   30500000.0       85.0
# 998  Alfred Hitchcock  Tallulah Bankhead        26471  852142728.0       78.0
# 999  Alfred Hitchcock       Robert Donat        51853  302787539.0       93.0

# %%
df.sample(5)
# Out:
#                 Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 339  Guardians of the Galaxy          2014      121  Action          8.0
# 878                Searching          2018      102   Drama          7.6
# 666         Lat sau san taam          1992      128  Action          7.8
# 823      Glengarry Glen Ross          1992      100   Crime          7.7
# 509            No Man's Land          2001       98  Comedy          7.9
#
#             Director          Star1  No_of_Votes        Gross  Metascore
# 339       James Gunn    Chris Pratt      1043455  333176600.0       76.0
# 878  Aneesh Chaganty       John Cho       140840   26020957.0       71.0
# 666         John Woo   Yun-Fat Chow        46700  565451439.0        NaN
# 823      James Foley      Al Pacino        95826   10725228.0       82.0
# 509    Danis Tanovic  Branko Djuric        44618    1059830.0       84.0

# %%
df[['Genre','Series_Title']]
# Out:
#       Genre              Series_Title
# 0     Drama  The Shawshank Redemption
# 1     Crime             The Godfather
# 2    Action           The Dark Knight
# 3     Crime    The Godfather: Part II
# 4     Crime              12 Angry Men
# ..      ...                       ...
# 995  Comedy    Breakfast at Tiffany's
# 996   Drama                     Giant
# 997   Drama     From Here to Eternity
# 998   Drama                  Lifeboat
# 999   Crime              The 39 Steps
#
# [1000 rows x 2 columns]

# %%
df['Genre'].value_counts().sort_values(ascending=False)
# Out:
# Drama        289
# Action       172
# Comedy       155
# Crime        107
# Biography     88
# Animation     82
# Adventure     72
# Mystery       12
# Horror        11
# Western        4
# Film-Noir      3
# Fantasy        2
# Family         2
# Thriller       1
# Name: Genre, dtype: int64

# %%
df['Genre'].value_counts().values.sum()
# Out:
# 1000

# %%
df[df['Genre']=='Action'].shape
# Out:
# (172, 10)

# %%
df['Released_Year'].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %%
df['Genre'].unique()
# Out:
# array(['Drama', 'Crime', 'Action', 'Biography', 'Western', 'Comedy',
#        'Adventure', 'Animation', 'Horror', 'Mystery', 'Film-Noir',
#        'Fantasy', 'Family', 'Thriller'], dtype=object)

# %%
l1=[1,2,3]
l2=[5,4,6]

l3=[1,2,3]
l4=[10,20,30]

# %%
df1 = pd.DataFrame({'ID': [1, 2, 3], 'Name': ['Alice', 'Bob', 'Charlie']})
df2 = pd.DataFrame({'ID': [1, 2, 4], 'Age': [25, 30, 35]})
merged_df = pd.merge(df1, df2, how='inner', on='ID')

# %%
merged_df
# Out:
#    ID   Name  Age
# 0   1  Alice   25
# 1   2    Bob   30

# %%
df1
# Out:
#    ID     Name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie

# %%
df2
# Out:
#    ID  Age
# 0   1   25
# 1   2   30
# 2   4   35

# %%
df2['Age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %%
df2['Age'].value_counts().sort_values(ascending=False)
# Out:
# 25    1
# 30    1
# 35    1
# Name: Age, dtype: int64

# %%
df1['Name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: Name, dtype: object

# %%
df['Director'].value_counts().sort_values(ascending=False)
# Out:
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Martin Scorsese     10
# Akira Kurosawa      10
#                     ..
# Jonathan Lynn        1
# Marc Caro            1
# David Zucker         1
# Mark Rydell          1
# George Stevens       1
# Name: Director, Length: 548, dtype: int64

# %%
df.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
df.tail()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 995  Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                   Giant          1956      201   Drama          7.6
# 997   From Here to Eternity          1953      118   Drama          7.6
# 998                Lifeboat          1944       97   Drama          7.6
# 999            The 39 Steps          1935       86   Crime          7.6
#
#              Director              Star1  No_of_Votes        Gross  Metascore
# 995     Blake Edwards     Audrey Hepburn       166544  679874270.0       76.0
# 996    George Stevens   Elizabeth Taylor        34075  195217415.0       84.0
# 997    Fred Zinnemann     Burt Lancaster        43374   30500000.0       85.0
# 998  Alfred Hitchcock  Tallulah Bankhead        26471  852142728.0       78.0
# 999  Alfred Hitchcock       Robert Donat        51853  302787539.0       93.0

# %%
df['Director'].unique()
# Out:
# array(['Frank Darabont', 'Francis Ford Coppola', 'Christopher Nolan',
#        'Sidney Lumet', 'Peter Jackson', 'Quentin Tarantino',
#        'Steven Spielberg', 'David Fincher', 'Robert Zemeckis',
#        'Sergio Leone', 'Lana Wachowski', 'Martin Scorsese',
#        'Irvin Kershner', 'Milos Forman', 'Thomas Kail', 'Bong Joon Ho',
#        'Sudha Kongara', 'Fernando Meirelles', 'Hayao Miyazaki',
#        'Roberto Benigni', 'Jonathan Demme', 'George Lucas',
#        'Masaki Kobayashi', 'Akira Kurosawa', 'Frank Capra',
#        'Todd Phillips', 'Damien Chazelle', 'Olivier Nakache',
#        'Roman Polanski', 'Ridley Scott', 'Tony Kaye', 'Bryan Singer',
#        'Luc Besson', 'Roger Allers', 'James Cameron',
#        'Giuseppe Tornatore', 'Isao Takahata', 'Alfred Hitchcock',
#        'Michael Curtiz', 'Charles Chaplin', 'Nadine Labaki', 'Can Ulkay',
#        'Gayatri', 'Makoto Shinkai', 'Nitesh Tiwari', 'Bob Persichetti',
# ...

# %%
df[df['Director']=='Frank Darabont'].shape
# Out:
# (2, 10)

# %%
df[df['Director']=='Francis Ford Coppola'].shape
# Out:
# (5, 10)

# %%
df[df['Director']=='Frank Darabont'].size
# Out:
# 20

# %%
df['Director'].value_counts()
# Out:
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Martin Scorsese     10
# Akira Kurosawa      10
#                     ..
# Neill Blomkamp       1
# Tomas Alfredson      1
# Duncan Jones         1
# Jacques Audiard      1
# George Stevens       1
# Name: Director, Length: 548, dtype: int64

# %%
df[['Director','Star1']]
# Out:
#                  Director              Star1
# 0          Frank Darabont        Tim Robbins
# 1    Francis Ford Coppola      Marlon Brando
# 2       Christopher Nolan     Christian Bale
# 3    Francis Ford Coppola          Al Pacino
# 4            Sidney Lumet        Henry Fonda
# ..                    ...                ...
# 995         Blake Edwards     Audrey Hepburn
# 996        George Stevens   Elizabeth Taylor
# 997        Fred Zinnemann     Burt Lancaster
# 998      Alfred Hitchcock  Tallulah Bankhead
# 999      Alfred Hitchcock       Robert Donat
#
# [1000 rows x 2 columns]
